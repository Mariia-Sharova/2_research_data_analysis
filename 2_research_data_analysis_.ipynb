# %% [markdown]
# <b> Проект: Исследовательский анализ данных</b>
#
# <b> Описание проекта</b>
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
#
# Ваша задача — выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
#
# О каждой квартире в базе содержится два типа данных: добавленные пользователем и картографические. Например, к первому типу относятся площадь квартиры, её этаж и количество балконов, ко второму — расстояния до центра города, аэропорта и ближайшего парка.
#
#
# <b> Инструкция по выполнению проекта</b>
#
#
# <b> Шаг 1. </b>
# * Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/real_estate_data.csv
# * Изучите общую информацию о полученном датафрейме.
# * Постройте общую гистограмму для всех числовых столбцов таблицы. Например, для датафрейма data это можно сделать командой data.hist(figsize=(15, 20)).
#
# <b> Шаг 2. Предобработка данных</b>
# * Найдите и изучите пропущенные значения в столбцах:
# * Определите, в каких столбцах есть пропуски.
# * Заполните пропущенные значения там, где это возможно. Например, если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски правильно заменить на 0. Если логичную замену предложить невозможно, то оставьте эти значения пустыми. Пропуски — тоже важный сигнал, который нужно учитывать.
# * В ячейке с типом markdown укажите причины, которые могли привести к пропускам в данных.
# Рассмотрите типы данных в каждом столбце:
# * Найдите столбцы, в которых нужно изменить тип данных.
# * Преобразуйте тип данных в выбранных столбцах.
# * В ячейке с типом markdown поясните, почему нужно изменить тип данных.
# * Изучите уникальные значения в столбце с названиями и устраните неявные дубликаты. Например, «поселок Рябово» и «поселок городского типа Рябово», «поселок Тельмана» и «посёлок Тельмана» — это обозначения одних и тех же населённых пунктов. Вы можете заменить названия в существующем столбце или создать новый с названиями без дубликатов.
# * Найдите и устраните редкие и выбивающиеся значения. Например, в столбце ceiling_height может быть указана высота потолков 25 м и 32 м. Логично предположить, что на самом деле это вещественные значения: 2.5 м и 3.2 м. Попробуйте обработать аномалии в этом и других столбцах.
# * Если природа аномалии понятна и данные действительно искажены, то восстановите корректное значение.
# В противном случае удалите редкие и выбивающиеся значения.
# * В ячейке с типом markdown опишите, какие особенности в данных вы обнаружили.
#
# <b> Шаг 3. Добавьте в таблицу новые столбцы со следующими параметрами:</b>
# * цена одного квадратного метра;
# * день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# * месяц публикации объявления;
# * год публикации объявления;
# * тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# * расстояние до центра города в километрах (переведите из м в км и округлите до целых значений).
#
# <b> Шаг 4. Проведите исследовательский анализ данных:</b>
# Изучите следующие параметры объектов:
# * общая площадь;
# * жилая площадь;
# * площадь кухни;
# * цена объекта;
# * количество комнат;
# * высота потолков;
# * этаж квартиры;
# * тип этажа квартиры («первый», «последний», «другой»);
# * общее количество этажей в доме;
# * расстояние до центра города в метрах;
# * расстояние до ближайшего аэропорта;
# * расстояние до ближайшего парка;
# * день и месяц публикации объявления.
# * Постройте отдельные гистограммы для каждого из этих параметров. Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
# * Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
#
# <b> Постройте гистограмму.</b>
# * Посчитайте среднее и медиану.
# * В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
# Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# * Изучите, зависит ли цена от:
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).
# * Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# * Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.
# * Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.
#
# <b> Шаг 5. Напишите общий вывод</b>
# * Опишите полученные результаты и зафиксируйте основной вывод проведённого исследования.
# Оформление
# * Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
# <b> Описание данных</b>
# airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# balcony — число балконов
# ceiling_height — высота потолков (м)
# cityCenters_nearest — расстояние до центра города (м)
# days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# first_day_exposition — дата публикации
# floor — этаж
# floors_total — всего этажей в доме
# is_apartment — апартаменты (булев тип)
# kitchen_area — площадь кухни в квадратных метрах (м²)
# last_price — цена на момент снятия с публикации
# living_area — жилая площадь в квадратных метрах (м²)
# locality_name — название населённого пункта
# open_plan — свободная планировка (булев тип)
# parks_around3000 — число парков в радиусе 3 км
# parks_nearest — расстояние до ближайшего парка (м)
# ponds_around3000 — число водоёмов в радиусе 3 км
# ponds_nearest — расстояние до ближайшего водоёма (м)
# rooms — число комнат
# studio — квартира-студия (булев тип)
# total_area — общая площадь квартиры в квадратных метрах (м²)
# total_images — число фотографий квартиры в объявлении
#
#
# <b> На что обращают внимание ревьюеры, когда проверяют ваш проект:</b>
# * Как вы описываете выявленные в данных проблемы?
# * Какие способы обработки пропусков вы применяете?
# * Как используете срезы данных?
# * Решают ли ваши графики поставленные задачи?
# * Какие методы построения графиков вы используете?
# * Выводите ли вы финальные данные в сводных таблицах?
# * Считаете ли показатели взаимосвязи в данных и как вы их объясняете?
# * Соблюдаете ли вы структуру проекта и поддерживаете ли аккуратность кода?
# * Какие выводы вы делаете?
# * Оставляете ли вы комментарии к шагам?

# %% [markdown]
# # 1. Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd
import seaborn as sns
import matplotlib .pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('real_estate_data.csv', sep = '\t')
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# # 1.1 Постройте гистограмму для всех числовых столбцов таблицы

# %%
data.hist(figsize=(15, 20));


# Предупреждения перед графиками можно убрать 2 способами:
# В конец кода добавить plt.show(), но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# В конец кода добавить ;

# %% [markdown]
# # 2. Предобработка данных

# %%
#Проверяю названия столбцов на возможные ошибки (пробелы, регистр, язык - все устраивает)
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %%
#Ищем количество пропущенных значений
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#Также мы можем посмотреть долю пропусков, и на основании этого принять решение о удалении, замене либо игнорировании пропусков
#Проверяем колличество пропусков в % 
pd.DataFrame(round(data.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_0152a_row0_col0, #T_0152a_row1_col0, #T_0152a_row2_col0, #T_0152a_row3_col0, #T_0152a_row4_col0, #T_0152a_row8_col0, #T_0152a_row10_col0, #T_0152a_row11_col0, #T_0152a_row14_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0152a_row5_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_0152a_row6_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_0152a_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_0152a_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0152a_row12_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_0152a_row13_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_0152a_row15_col0, #T_0152a_row16_col0, #T_0152a_row17_col0, #T_0152a_row19_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_0152a_row18_col0 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_0152a_row20_col0 {
# ...

# %% [markdown]
# Самое большое количество пропусков в ceiling_height, is_apartment, balcony, parks_nearest, ponds_nearest
#
# Пропуски в балконах, ближайших парках, водоемах, апартаментах - вполне понятны, для многих это необязательная категория. Также большинство квартир не являются апартаментами на рынке недвижимости, вероятно поэтому там самый большой процент пропусков.
# Пропуски в высоте потолков возможны из-за ошибок в данных либо же по какой-то причине люди не заполняют это графу. Возможно не знают высоту потолков или считают эту графу менее существенной, чем другие параметры.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
#Меняем формат object в столбце first_day_exposition на формат datetime
data['first_day_exposition'] = pd.to_datetime(
    data['first_day_exposition'], format='%Y.%m.%dT%H:%M:%S')

#При чтении файла можно было указать параметр parse_dates: parse_dates=['first_day_exposition'].
#Тогда пандас автоматически переведет список столбцов в даты.

# %%
#Заменяем пропуски в балконах на 0 (скорее всего данные не указаны, так как былконы в квартирах отсутствуют, а продавцы просто не указывают невыгодные для продажи характеристики) и приводим столбец к целочисленному типу
data['balcony'] = data['balcony'].fillna(0)
data['balcony'] = data['balcony'].astype('int')

# %% [markdown]
# Остальные изменения типа данных в столбцах уже не так очевидны. Вернемся к ним после того, как рассмотрим данные подробнее: найдем и заполним пропуски, а также разберемся с дубликатами.

# %%
data['total_images'].describe()
#Проверяем уникальные значения в столбце total_images
# Out:
# count    23699.000000
# mean         9.858475
# std          5.682529
# min          0.000000
# 25%          6.000000
# 50%          9.000000
# 75%         14.000000
# max         50.000000
# Name: total_images, dtype: float64

# %%
data['last_price'].describe()
#Проверяем основную информацию в столбце last_price
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['total_area'].describe()
#Проверяем основную информацию в столбце total_area
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Согласно открытым источникам, общая площадь квартиры не может быть менее 20 кв.м.
# https://gsps.ru/poleznoe/minimalnaya-ploshchad-pomeshcheniy-kvartiry.php

# %%
data.drop(data[data['total_area']<20].index,inplace=True)
#удаляем данные квартиры, данные здесь восстановить не получится

# %%
data['rooms'].unique()
# Out:
# array([ 3,  1,  2,  4,  5,  6,  0,  7, 11,  8, 14, 10, 15,  9, 19, 16, 12],
#       dtype=int64)

# %%
data.sort_values(by='rooms').head(20)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 20254             5   3200000.0       23.60           2018-07-13      0
# 17182            14   1990000.0       24.40           2017-01-23      0
# 946               5   2200000.0       23.00           2016-09-27      0
# 21478             3   3100000.0       22.70           2018-08-22      0
# 14064             8   1400000.0       24.00           2017-05-24      0
# 11035             1   2500000.0       26.00           2017-11-10      0
# 21628             9   3900000.0       34.00           2017-03-18      0
# 19917             5   2340000.0       25.41           2017-09-29      0
# 1277             10   3150000.0       26.00           2017-07-14      0
# 608               2   1850000.0       25.00           2019-02-20      0
# 12691             1   3700000.0       24.20           2017-11-10      0
# 17824            10   2300000.0       22.50           2017-09-27      0
# ...

# %% [markdown]
# Есть значения, где число комнат = 0
# Есть гипотеза, что таким образом указаны квартиры-студии и квартиры со свободной планировкой.
# Используем срез данных, чтобы это узнать.

# %%
data.query('rooms == 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1   2450000.0       27.00           2017-03-30      0
# 349               4   2320000.0       25.00           2017-09-27      0
# 440               8   2480000.0       27.11           2018-03-12      0
# 508               0   3375000.0       34.40           2017-03-28      0
# 608               2   1850000.0       25.00           2019-02-20      0
# ...             ...         ...         ...                  ...    ...
# 23210             7   3200000.0       26.00           2017-09-01      0
# 23442             0   2500000.0       27.70           2017-09-28      0
# 23554            15   3350000.0       26.00           2018-09-07      0
# 23592            10   1450000.0       29.00           2017-11-11      0
# 23637             8   2350000.0       26.00           2018-06-26      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.query('studio == True and rooms == 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1   2450000.0       27.00           2017-03-30      0
# 440               8   2480000.0       27.11           2018-03-12      0
# 608               2   1850000.0       25.00           2019-02-20      0
# 697              12   2500000.0       24.10           2017-12-01      0
# 1173             12   3240000.0       29.00           2018-10-30      0
# ...             ...         ...         ...                  ...    ...
# 22867             8   3090000.0       30.00           2017-12-17      0
# 22877             2   4280000.0       28.00           2017-10-26      0
# 23210             7   3200000.0       26.00           2017-09-01      0
# 23554            15   3350000.0       26.00           2018-09-07      0
# 23637             8   2350000.0       26.00           2018-06-26      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.query('open_plan == True and rooms == 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 349               4   2320000.0       25.00           2017-09-27      0
# 508               0   3375000.0       34.40           2017-03-28      0
# 780               9   2600000.0       26.10           2018-02-20      0
# 839              14   1900000.0       35.00           2017-04-14      0
# 946               5   2200000.0       23.00           2016-09-27      0
# 1574              0   2200000.0       22.00           2017-11-03      0
# 1625              7   1980000.0       23.98           2018-02-01      0
# 2532              5   3500000.0       27.10           2018-02-01      0
# 3019             18   2100000.0       24.00           2017-11-10      0
# 4115              7   2600000.0       24.00           2018-02-01      0
# 4437             10   3200000.0       25.00           2017-10-16      0
# 4683              2   3650000.0       35.00           2018-02-01      0
# ...

# %% [markdown]
# 95% данных соответствуют данному условию (180 из 189 строк).
# Вероятно, что объявления, где указано 0 комнат, являются студиями или свободными планировками. Не трогаем эти данные.

# %%
#Далее проверяем уникальные значения в столбце
data['floors_total'].unique()
# Out:
# array([16., 11.,  5., 14., 12., 26., 24., 27.,  9.,  6., 17., 25.,  3.,
#        23., 19., 18.,  4., 22.,  8.,  2., 10.,  7., 13., 15., nan, 20.,
#        28., 36., 21., 35., 34., 60.,  1., 29., 33., 52., 37.])

# %%
data.query('floors_total > 37')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 2253             12   3800000.0        45.5           2018-06-28      2
# 16731             9   3978000.0        40.0           2018-09-24      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 2253             2.88          60.0         27.4      4          NaN  ...
# 16731            2.65          52.0         10.5     18          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 2253            7.4        0        Кронштадт           67763.0
# 16731          14.0        0  Санкт-Петербург           20728.0
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 2253              49488.0               2.0          342.0               3.0
# 16731             12978.0               1.0          793.0               0.0
#
#        ponds_nearest  days_exposition
# 2253           614.0            166.0
# ...

# %% [markdown]
# По данным https://guideburg.com/ru/blog/10-samykh-vysokikh-zdaniy-peterburga/ максимальное количество этажей в жилых зданиях
# Санкт-Петербурга  = 37 этажей
# Следовательно имеем аномальные значения, удалим эти две строки.

# %%
data.drop(data[data['floors_total']>37].index,inplace=True)

# %%
data.sort_values(by='floors_total', ascending=False)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 16934             5   4100000.0        40.0           2017-10-17      1
# 397              15   5990000.0        54.0           2018-03-22      2
# 11079            16   9200000.0        75.0           2019-02-22      2
# 5807             17   8150000.0        80.0           2019-01-09      2
# 5808             12   4590000.0        43.0           2018-10-19      1
# ...             ...         ...         ...                  ...    ...
# 22542             5   8500000.0        63.5           2017-05-24      2
# 22656             4   4574160.0        64.5           2017-04-02      2
# 22808             0  14569263.0       110.4           2016-11-20      3
# 23590             0  21187872.0       123.3           2017-04-25      3
# 23658             6   3063600.0        43.8           2016-11-28      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
#Так как работаем с количественными переменными, не будем удалять строки с пропущенными значениями, а заменим их на максимально возможное значение. На медиану менять не имеет смысла, так как в итоге этаж квартиры может оказаться выше, чем этажность дома.
data['floors_total'] = data['floors_total'].fillna(data['floors_total'].max())

# %%
data['floors_total'].value_counts()
# Out:
# 5.0     5775
# 9.0     3757
# 16.0    1375
# 12.0    1362
# 4.0     1198
# 10.0    1174
# 25.0    1075
# 6.0      912
# 17.0     833
# 3.0      666
# 7.0      592
# 14.0     553
# 18.0     505
# 24.0     469
# 8.0      390
# 2.0      382
# 15.0     365
# 23.0     351
# 19.0     338
# 22.0     286
# 20.0     271
# 13.0     229
# 11.0     203
# 27.0     164
# 21.0     158
# 26.0     124
# 37.0      87
# 1.0       25
# 35.0      24
# 28.0      21
# 36.0       3
# 34.0       1
# 29.0       1
# 33.0       1
# Name: floors_total, dtype: int64

# %%
#Заменим тип данных на целочисленный
data['floors_total'] = data['floors_total'].astype('int')

# %%
data['floors_total'].unique()
data['floors_total'] = data['floors_total'].round()

# %%
data['floors_total'].unique()
# Out:
# array([16, 11,  5, 14, 12, 26, 24, 27,  9,  6, 17, 25,  3, 23, 19, 18,  4,
#        22,  8,  2, 10,  7, 13, 15, 37, 20, 28, 36, 21, 35, 34,  1, 29, 33])

# %%
#Далее работаем со столбцом ceiling_height ("высота потолков")
data.sort_values(by='ceiling_height', ascending=False)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22869             0  15000000.0        25.0           2018-07-25      1
# 22336            19   9999000.0        92.4           2019-04-05      2
# 3148             14   2900000.0        75.0           2018-11-12      3
# 21377            19   4900000.0        42.0           2017-04-18      1
# 5246              0   2500000.0        54.0           2017-10-13      2
# ...             ...         ...         ...                  ...    ...
# 23687             6   3200000.0        39.0           2017-12-16      1
# 23690             3   5500000.0        52.0           2018-07-19      2
# 23692             2   1350000.0        30.0           2017-07-07      1
# 23695            14   3100000.0        59.0           2018-01-15      3
# 23696            18   2500000.0        56.7           2018-02-11      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Высоту потолков в многоквартирных домах стандартной застройки регламентирует п. 5.8 СНиП 31-01-2003. Согласно этому документу, высота потолка зависит от климатических условий в конкретном районе, а также от назначения и типа комнаты. В теплых зонах потолок должен располагаться на высоте не менее 2,7 метра, а для остальных районов минимальная высота потолка составляет 2,5 метра.
#
# Максимальная высота не регламентирована. На сайте Яндекс недвижимости в текущих объявлениях были найдены потолки с максимальной высотой - 4,5 метра (старый фонд).
#
# Следовательно, считаем выбросами высоту потолков менее 2,5 метров и более 4,5 метров.
#
# Также здесь допускаем, что была допущена ошибка в типах данных и вмето потолка 32 метра указан потолок 3,2 метра.

# %%
data['ceiling_height'] = data['ceiling_height']/10

# %%
#заполним отсутствующие значения средним значением
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %%
data.sort_values(by='ceiling_height', ascending=False)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22869             0  15000000.0        25.0           2018-07-25      1
# 3148             14   2900000.0        75.0           2018-11-12      3
# 22336            19   9999000.0        92.4           2019-04-05      2
# 21377            19   4900000.0        42.0           2017-04-18      1
# 20478            11   8000000.0        45.0           2017-07-18      1
# ...             ...         ...         ...                  ...    ...
# 2572              4   2400000.0        62.0           2018-12-27      3
# 16884             0   1500000.0        33.0           2018-10-03      1
# 16934             5   4100000.0        40.0           2017-10-17      1
# 5712              5   1500000.0        42.8           2017-08-14      2
# 22590            16   6000000.0        55.0           2018-10-31      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
#Код ревьюера
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23670 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23670 non-null  int64
#  1   last_price            23670 non-null  float64
#  2   total_area            23670 non-null  float64
#  3   first_day_exposition  23670 non-null  datetime64[ns]
#  4   rooms                 23670 non-null  int64
#  5   ceiling_height        23670 non-null  float64
#  6   floors_total          23670 non-null  int32
#  7   living_area           21776 non-null  float64
#  8   floor                 23670 non-null  int64
#  9   is_apartment          2771 non-null   object
#  10  studio                23670 non-null  bool
#  11  open_plan             23670 non-null  bool
#  12  kitchen_area          21415 non-null  float64
#  13  balcony               23670 non-null  int32
# ...

# %%
#Удаляем выбросы, где высота потолков менее 2,5 метров и более 4,5 метров
# data.drop(data[data['ceiling_height']>4.5].index,inplace=True)
# data.drop(data[data['ceiling_height']<2.5].index,inplace=True)

# %%
data['ceiling_height'].unique()
# Out:
# array([ 0.27 ,  0.265,  0.303,  0.25 ,  0.267,  0.256,  0.305,  0.275,
#         0.26 ,  0.29 ,  0.28 ,  0.255,  0.3  ,  0.32 ,  0.261,  0.325,
#         0.345,  0.277,  0.285,  0.264,  0.257,  0.415,  0.35 ,  0.33 ,
#         0.271,  0.4  ,  0.247,  0.273,  0.284,  0.31 ,  0.234,  0.34 ,
#         0.306,  0.272,  0.254,  0.251,  0.278,  0.276,  2.5  ,  0.258,
#         0.37 ,  0.252,  0.52 ,  0.287,  0.266,  0.259,  0.2  ,  0.245,
#         0.36 ,  0.292,  0.311,  0.313,  0.38 ,  0.315,  0.355,  0.316,
#         0.362,  0.312,  0.253,  0.274,  0.296,  0.246,  0.53 ,  0.5  ,
#         0.279,  0.295,  0.406,  0.294,  0.382,  0.354,  0.353,  0.283,
#         0.47 ,  0.24 ,  0.338,  0.301,  0.56 ,  0.365,  0.39 ,  0.318,
#         0.335,  0.23 ,  0.357,  0.248,  0.262,  0.282,  0.398,  0.263,
#         0.383,  0.352,  0.395,  0.375,  0.367,  0.387,  0.366,  0.385,
#         0.386,  0.419,  0.324,  0.48 ,  0.45 ,  0.42 ,  0.336,  3.2  ,
# ...

# %%
#Стоит провожить фильтрацию аккуратно, если выбросы составляют более 10%, то это уже один из трендов.
#До обработки аномалий мы можем заполнить пропуски в потолках медианой.

# %%
#Код ревьюера
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23670 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23670 non-null  int64
#  1   last_price            23670 non-null  float64
#  2   total_area            23670 non-null  float64
#  3   first_day_exposition  23670 non-null  datetime64[ns]
#  4   rooms                 23670 non-null  int64
#  5   ceiling_height        23670 non-null  float64
#  6   floors_total          23670 non-null  int32
#  7   living_area           21776 non-null  float64
#  8   floor                 23670 non-null  int64
#  9   is_apartment          2771 non-null   object
#  10  studio                23670 non-null  bool
#  11  open_plan             23670 non-null  bool
#  12  kitchen_area          21415 non-null  float64
#  13  balcony               23670 non-null  int32
# ...

# %% [markdown]
# Далее рассмотрим данные с указанием жилой площади
# Согласно данным из открытых источников, жилая площадь не может быть менее 8 кв.м.
# https://gsps.ru/poleznoe/minimalnaya-ploshchad-pomeshcheniy-kvartiry.php
# data.sort_values(by='living_area'). Удалим выбросы.

# %%
data.query('living_area <8.0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3242              7   4440000.0        41.0           2017-07-02      1
# 13915            20   6350000.0        52.0           2018-02-06      2
# 16431            13   3799000.0        31.0           2018-04-12      1
# 17582            11   2680000.0        22.0           2018-08-11      0
# 19251            19   4050000.0        33.0           2018-10-15      1
# 21758             0   2330000.0        23.0           2018-01-01      0
# 21943            15   6100000.0        77.6           2019-02-28      4
# 23574            14  64990000.0       139.0           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 3242            0.265            17          3.0     17          NaN  ...
# 13915           0.300             6          2.0      2          NaN  ...
# 16431           0.260             5          6.0      1          NaN  ...
# ...

# %%
data.drop(data[data['living_area']<8].index,inplace=True)

# %%
#Максимальное значение выбросом не считаю, вполне допустим подобный метраж квартиры, например, в случае объединения нескольких квартир
data['living_area'].max()
# Out:
# 409.7

# %%
data['living_area'].min()
# Out:
# 8.0

# %%
data['living_area'].isna().sum()
# Out:
# 1894

# %% [markdown]
# Есть пропуски в жилой площади квартиры (менее 5% от всех данных). Возможно, авторы объявлений не заполнили этот пункт, указав только общую площадь. Не вижу смысла заполнять эти пропуски, значения могут быть в итоге некорректными.

# %%
#Далее рассмотрим floor
data['floor'].unique()
# Out:
# array([ 8,  1,  4,  9, 13,  5,  6, 22, 26,  7,  3,  2, 11, 15, 18, 10, 19,
#        16, 20, 27, 25, 17, 14, 12, 21, 28, 24, 23, 30, 29, 32, 33, 31],
#       dtype=int64)

# %%
#Отсутствуют данные о квартирах-апартаментах
data.query('is_apartment == "True"')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Данные о квартирах-апартаментах в объявлениях отсутствуют. Видим значения False и Nan, эти данные мы заполнить не можем, оставим, как есть. Делаем вывод, что либо апартаменты здесь отсутствуют, либо авторы объявлений решили не указывать, что квартира является апартаментом, так как такие квартиры изначально не предназначены для постоянного проживания и юридичеси не являются жилым помещением

# %%
#Квартиры-студии в виде булева типа. Можем посчитать, что их процент от всех объявлений всего 0.7%
data['studio'].mean()
# Out:
# 0.005916659623024258

# %%
#Со свободной планировкой 0.5% от всех объявлений
data['open_plan'].mean()
# Out:
# 0.002789282393711436

# %% [markdown]
# Далее рассмотрим площадь кухни
# По нормативной площади помещений квартиры минимальная площадь кухни составляет 5 кв.м.
# https://www.houzz.ru/statyi/kak-pravilyno-planirovka-uzkih-i-malenykih-kuhony-stsetivw-vs~96366934
# Удалим данные с меньшей площадью.

# %%
data.query('kitchen_area <5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 76               12   2800000.0        55.1           2016-05-14      3
# 298               9   2650000.0        42.8           2017-04-25      2
# 422               8   1700000.0        55.2           2018-03-24      3
# 906              15   2600000.0        27.0           2017-07-10      1
# 1327              6   2650000.0        46.2           2016-12-01      2
# ...             ...         ...         ...                  ...    ...
# 22839            14   3350000.0        27.0           2018-11-03      1
# 22849             6   2380000.0        25.0           2016-03-22      1
# 23110             1   2900000.0        34.0           2018-02-01      2
# 23498             7   1600000.0        54.0           2016-12-26      2
# 23678            10   3500000.0        43.0           2016-05-19      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.drop(data[data['kitchen_area']<5].index,inplace=True)

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2253

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(data['kitchen_area'].median())

# %%
#Максимальное значение не считаю выбросом, не удалаяю
#Это может быть большая квартира, объединенная из нескольких, с перепланировкой
data['kitchen_area'].max()
# Out:
# 112.0

# %%
#5 балконов не считаю за выброс, это может быть большая объединенная из нескольких квартира
data['balcony'].unique()
# Out:
# array([0, 2, 1, 5, 4, 3])

# %%
len(data['locality_name'].unique())
# Out:
# 364

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23561 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23561 non-null  int64
#  1   last_price            23561 non-null  float64
#  2   total_area            23561 non-null  float64
#  3   first_day_exposition  23561 non-null  datetime64[ns]
#  4   rooms                 23561 non-null  int64
#  5   ceiling_height        23561 non-null  float64
#  6   floors_total          23561 non-null  int32
#  7   living_area           21668 non-null  float64
#  8   floor                 23561 non-null  int64
#  9   is_apartment          2759 non-null   object
#  10  studio                23561 non-null  bool
#  11  open_plan             23561 non-null  bool
#  12  kitchen_area          23561 non-null  float64
#  13  balcony               23561 non-null  int32
# ...

# %%
#Устраняем неявные дубликаты в названийх населенных пунктов
data['locality_name'] = data['locality_name'].str.replace('ё', 'е')

# %%
data['locality_name'] = data['locality_name'].str.replace('городской поселок','поселок городского типа')

# %%
data['locality_name'] = data['locality_name'].str.lower()
#Приведем названия к нижнему регистру

# %%
# Можно было еще применить такой подход:
    
#df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))

#len(df.locality_name.unique())

# %%
'Количество явных дубликатов:', data.duplicated().sum()
# Out:
# ('Количество явных дубликатов:', 0)

# %%
#меняем расстояние до аэропорта, до центра города, парка и ближайшего водоема с метров на километры
#поступаем так с расстоянием до аэропорта, 

data['airports_nearest'] = data['airports_nearest']/1000

data['cityCenters_nearest'] = round(data['cityCenters_nearest']/1000)
#расстояние до центра города округлила и перевела в км

data['parks_nearest'] = data['parks_nearest']/1000

data['ponds_nearest'] = data['ponds_nearest']/1000

# %%
#Мы имеем право заполнять данные только тогда, когда они пропущены совершенно случайно (MCAR) -
#тогда заполнение не повлияет на характер связи между заполняемой переменной и остальными.
#Обработка пропусков медианой в данном случае невозможна.

# %%
#Если пропущенные значения в данных о парках и водоемах в радиусе 3 км отсутствуют, допускаю, что парки и водоемы отсутствуют в принципе. Заменим на 0 пропуски.
data['parks_around3000'] = data['parks_around3000'].fillna(0)
data['ponds_around3000'] = data['ponds_around3000'].fillna(0)
#заменим вещественное число на целое для красоты
data['parks_around3000'] = data['parks_around3000'].astype('int')
data['ponds_around3000'] = data['ponds_around3000'].astype('int')

# %% [markdown]
# На колонку days_exposition мы никак не можем повлиять. Оставляем, как есть.

# %%
#Код ревьюера
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23561 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23561 non-null  int64
#  1   last_price            23561 non-null  float64
#  2   total_area            23561 non-null  float64
#  3   first_day_exposition  23561 non-null  datetime64[ns]
#  4   rooms                 23561 non-null  int64
#  5   ceiling_height        23561 non-null  float64
#  6   floors_total          23561 non-null  int32
#  7   living_area           21668 non-null  float64
#  8   floor                 23561 non-null  int64
#  9   is_apartment          2759 non-null   object
#  10  studio                23561 non-null  bool
#  11  open_plan             23561 non-null  bool
#  12  kitchen_area          23561 non-null  float64
#  13  balcony               23561 non-null  int32
# ...

# %% [markdown]
# # 3. Посчитайте и добавьте в таблицу новые столбцы
#
# * цена одного квадратного метра;
# * день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# * месяц публикации объявления;
# * год публикации объявления;
# * тип этажа квартиры (значения — «‎первый», «последний», «другой»);

# %%
data['meter_price'] = data['last_price'] / data['total_area']
#цена одного квадратного метра

# %%
data['day'] = data['first_day_exposition'].dt.weekday
#день недели публикации объявления

# %%
data['month'] = data['first_day_exposition'].dt.month
#месяц публикации объявления

# %%
data['year'] = data['first_day_exposition'].dt.year
#год публикации объявления

# %%
#тип этажа квартиры (значения — «первый», «последний», «другой»)

def type_fl(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == floors_total:
        return 'последний'
    if floor == 1:
        return 'первый'
    return 'другой'
   
data['type_floor'] = data.apply(type_fl, axis=1)

# %% [markdown]
# # 4. Проведите исследовательский анализ данных
#
# Изучите следующие параметры объектов:
# * общая площадь;
# * жилая площадь;
# * площадь кухни;
# * цена объекта;
# * количество комнат;
# * высота потолков;
# * этаж квартиры;
# * тип этажа квартиры («первый», «последний», «другой»);
# * общее количество этажей в доме;
# * расстояние до центра города в метрах;
# * расстояние до ближайшего аэропорта;
# * расстояние до ближайшего парка;
# * день и месяц публикации объявления.
# * Постройте отдельные гистограммы для каждого из этих параметров. Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.
# * Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.
#
# <b> Постройте гистограмму.</b>
# * Посчитайте среднее и медиану.
# * В ячейке типа markdown опишите, сколько времени обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?
# Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# * Изучите, зависит ли цена от:
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).
# * Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# * Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.
# * Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23561.000000  2.356100e+04  23561.000000  23561.000000    23561.000000
# mean       9.866092  6.559107e+06     60.501382      2.074063        0.272476
# std        5.684625  1.090812e+07     35.679998      1.078769        0.099106
# min        0.000000  1.219000e+04     20.000000      0.000000        0.100000
# 25%        6.000000  3.450000e+06     40.000000      1.000000        0.260000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        0.265000
# 75%       14.000000  6.800000e+06     70.000000      3.000000        0.270000
# max       50.000000  7.630000e+08    900.000000     19.000000       10.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23561.000000  21668.000000  23561.000000  23561.000000  23561.000000
# mean      10.780188     34.531608      5.899410     10.467368      0.592038
# ...

# %%
#общая площадь
data.hist('total_area',bins=100, range=(20,100))
#используем range для определения пиковых значений.
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>]], dtype=object)

# %% [markdown]
# Наибольшее количество квартир в продаже - с общей площадью около 45 кв метров

# %%
data.boxplot('total_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Большинство продаваемых квартир имеют площадь до 75 кв метров. Есть редкие значения свыше 80 кв метров - это более редкое и дорогое жилье

# %%
data['total_area'].describe()
# Out:
# count    23561.000000
# mean        60.501382
# std         35.679998
# min         20.000000
# 25%         40.000000
# 50%         52.000000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Для более корректного анализа надо определиться, что считать выбросами. По describe() и диаграмме размаха видим, что почти все объекты у нас до 75 кв метров

# %%
pivot_total_area = data.pivot_table(
    index='rooms',
    values='total_area'
)
pivot_total_area
# Out:
#        total_area
# rooms
# 0       29.841230
# 1       37.756792
# 2       55.928145
# 3       77.801357
# 4      107.675806
# 5      161.474816
# 6      201.537619
# 7      265.325424
# 8      259.233333
# 9      305.975000
# 10     259.566667
# 11     188.900000
# 12     900.000000
# 14     304.200000
# 15     590.000000
# 16     270.000000
# 19     374.600000

# %%
data['rooms'].value_counts()
# Out:
# 1     7978
# 2     7897
# 3     5800
# 4     1178
# 5      326
# 0      187
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# 12       1
# Name: rooms, dtype: int64

# %%
total_area = data['total_area']
rooms = data['rooms']
sns.barplot(x = rooms, y = total_area, ci=None);

# %% [markdown]
# Чем больше комнат, тем больше общая площадь квартиры

# %% [markdown]
# Мы помни, что основная масса объектов в продаже - до 75 кв метров, но если удалим все, что свыше, пропадут из анализа 3 и 4 комнатные квартиры
#
# 5-комнатные квартиры и выше уже большая редкость
# Как выяснили выше, средняя площадь таких квартир - 161 кв м, что является редкостью.
# Поэтому будем считать выбросами квартиры от 5 комнат и выше, а 3 и 4 комнатные квартиры оставим, как есть.

# %%
data.drop(data[data['rooms'] > 4].index,inplace=True)

# %%
data['total_area'].describe()
# Out:
# count    23040.000000
# mean        57.576325
# std         26.589481
# min         20.000000
# 25%         40.000000
# 50%         51.300000
# 75%         68.000000
# max        500.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Удалим выбросы в total_area

# %%
data.boxplot('living_area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Средняя жилая площадь = 30 кв м, в основном к продаже находятся квартиры с жилой площадью до 55 кв м

# %%
data.plot(x='total_area',y='living_area',kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='total_area', ylabel='living_area'>

# %% [markdown]
# Все вполне закономерно: растет общая площадь и вместе с ней растет жилай площадь

# %%
#Чем больше комнат в квартире,тем выше общая площадь,
data.pivot_table(
    index='rooms',
    values='total_area'
)
pivot_total_area
# Out:
#        total_area
# rooms
# 0       29.841230
# 1       37.756792
# 2       55.928145
# 3       77.801357
# 4      107.675806
# 5      161.474816
# 6      201.537619
# 7      265.325424
# 8      259.233333
# 9      305.975000
# 10     259.566667
# 11     188.900000
# 12     900.000000
# 14     304.200000
# 15     590.000000
# 16     270.000000
# 19     374.600000

# %% [markdown]
# Все логично: с количеством комнат возрастает и общая площадь объекта

# %%
#жилая площадь
data['living_area'].describe()
# Out:
# count    21194.000000
# mean        32.632722
# std         16.412064
# min          8.000000
# 25%         18.500000
# 50%         30.000000
# 75%         41.900000
# max        250.000000
# Name: living_area, dtype: float64

# %%
#площадь кухни
data['kitchen_area'].describe()
# Out:
# count    23040.000000
# mean        10.280427
# std          5.244707
# min          5.000000
# 25%          7.300000
# 50%          9.200000
# 75%         11.200000
# max        107.000000
# Name: kitchen_area, dtype: float64

# %%
data['last_price']
# Out:
# 0        13000000.0
# 1         3350000.0
# 2         5196000.0
# 3        64900000.0
# 4        10000000.0
#             ...
# 23694     9700000.0
# 23695     3100000.0
# 23696     2500000.0
# 23697    11475000.0
# 23698     1350000.0
# Name: last_price, Length: 23040, dtype: float64

# %%
#цена объекта
data.hist('last_price', range=(0,5000000))
# Out:
# array([[<AxesSubplot:title={'center':'last_price'}>]], dtype=object)

# %% [markdown]
# data['last_price'].describe()

# %%
#количество комнат
data.hist('rooms')
# Out:
# array([[<AxesSubplot:title={'center':'rooms'}>]], dtype=object)

# %% [markdown]
# Самое большое количество квартир, представленных в продаже - 1 и 2 комнатные

# %% [markdown]
# Однокомнатные популярней по ряду причин: цена(доступней для одиноких людей, а также людям в гражданском браке), рентабельность(покупка с целью продать дороже, а так же сдача в наём для приезжих, студентов и т.д), наследство.

# %%
#высота потолков

data.hist('ceiling_height', bins=3)
data['ceiling_height'].describe()
# Out:
# count    23040.000000
# mean         0.271731
# std          0.099849
# min          0.100000
# 25%          0.260000
# 50%          0.265000
# 75%          0.270000
# max         10.000000
# Name: ceiling_height, dtype: float64

# %%
#этаж квартиры

data.hist('floor')
data['floor'].value_counts().head(10)
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# Name: floor, dtype: int64

# %% [markdown]
# Довольно мало квартир продается на высоких этажах.

# %%
#общее количество этажей в доме
data.hist('floors_total')
data['floors_total'].describe()
# Out:
# count    23040.000000
# mean        10.871007
# std          6.768693
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         37.000000
# Name: floors_total, dtype: float64

# %%
#Код ревьюера

sns.histplot(data['type_floor'], kde=False, bins=30)
plt.xlim(0,3)
plt.title('Тип этажа квартиры')
plt.xlabel('Тип этажа квартиры')
plt.ylabel('Частота')
plt.show()

# %%
#расстояние до центра города в км
data.hist('cityCenters_nearest')

data['cityCenters_nearest'].describe()
# Out:
# count    17593.000000
# mean        14.375547
# std          8.536135
# min          0.000000
# 25%         10.000000
# 50%         13.000000
# 75%         16.000000
# max         66.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# 75% объявлений находятся в пределах 15 км от центра. Довольно близко!

# %%
data_two = data[['locality_name', 'cityCenters_nearest']]
data_two.query('cityCenters_nearest>15').head(30)
# Out:
#             locality_name  cityCenters_nearest
# 0         санкт-петербург                 16.0
# 1          поселок шушары                 19.0
# 6       поселок парголово                 19.0
# 11              ломоносов                 52.0
# 13               петергоф                 33.0
# 14                 пушкин                 31.0
# 20      поселок парголово                 19.0
# 28                 пушкин                 31.0
# 33                колпино                 32.0
# 36        санкт-петербург                 16.0
# 40      поселок парголово                 19.0
# 42               петергоф                 31.0
# 48        санкт-петербург                 17.0
# 49        санкт-петербург                 17.0
# 50                 пушкин                 30.0
# 53      поселок парголово                 19.0
# 57         поселок шушары                 19.0
# 58        санкт-петербург                 16.0
# 67              ломоносов                 51.0
# ...

# %% [markdown]
# Где-то указан просто город Санкт-Петербург, но в целом во многих объявлениях указан конкретный населенный пункт (ближайшие пригороды)

# %%
data_two.query('cityCenters_nearest>15 and locality_name!="Санкт-Петербург"').head(30)
# Out:
#             locality_name  cityCenters_nearest
# 0         санкт-петербург                 16.0
# 1          поселок шушары                 19.0
# 6       поселок парголово                 19.0
# 11              ломоносов                 52.0
# 13               петергоф                 33.0
# 14                 пушкин                 31.0
# 20      поселок парголово                 19.0
# 28                 пушкин                 31.0
# 33                колпино                 32.0
# 36        санкт-петербург                 16.0
# 40      поселок парголово                 19.0
# 42               петергоф                 31.0
# 48        санкт-петербург                 17.0
# 49        санкт-петербург                 17.0
# 50                 пушкин                 30.0
# 53      поселок парголово                 19.0
# 57         поселок шушары                 19.0
# 58        санкт-петербург                 16.0
# 67              ломоносов                 51.0
# ...

# %%
#расстояние до ближайшего аэропорта

data.hist('airports_nearest')
data['airports_nearest'].describe()
# Out:
# count    17572.000000
# mean        28.895302
# std         12.712637
# min          0.000000
# 25%         18.488000
# 50%         26.995000
# 75%         37.412000
# max         84.869000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Среднее расстояние до аэропорта около 23 км. Аэропорт в Санкт-Петербурге удален от центра города и находится в южной его части.

# %%
#расстояние до ближайшего парка

data.hist('parks_nearest')
data['parks_nearest'].describe()
# Out:
# count    7715.000000
# mean        0.494186
# std         0.345415
# min         0.001000
# 25%         0.288000
# 50%         0.456000
# 75%         0.616000
# max         3.190000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# В среднем в радиусе 450 метров имеются водооемы

# %%
#день недели публикации объявления

data.hist('day')
data['day'].describe()
# Out:
# count    23040.000000
# mean         2.570052
# std          1.789535
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# Name: day, dtype: float64

# %%
#месяц публикации объявления

data.hist('month')
data['month'].value_counts()
# Out:
# 2     2563
# 3     2504
# 4     2324
# 11    2301
# 10    2073
# 9     1928
# 6     1712
# 8     1702
# 7     1639
# 12    1599
# 1     1464
# 5     1231
# Name: month, dtype: int64

# %% [markdown]
# В летние месяцы активность публикаций объявлений сильно спадает

# %%
data.hist('balcony')
# Out:
# array([[<AxesSubplot:title={'center':'balcony'}>]], dtype=object)

# %% [markdown]
# С балконами все хорошо, гистограмма выглядит нормально. Есть провал с 3 балконами. Возможно, зависит от типа жилья.

# %%
#Как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.

data.hist('days_exposition')
data['days_exposition'].describe()
# Out:
# count    20005.000000
# mean       178.886178
# std        217.476993
# min          1.000000
# 25%         45.000000
# 50%         94.000000
# 75%        228.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# 157 дней (полгода) - в среднем на столько дней объявления размещаются на сайте.
#
# Медиана  = 72 дням, так как мы имеем квартиры, которые продавались годами. Максимально размещение объявления по нашим данным было 1580 дней (более 4 лет). Похоже на ошибки в данных, возможно, это объявления с истекшим сроком. Данный выброс в 15 раз больше верхнего квартиля.
# Поэтому предлагаю ориентироваться на межквартильный размах для расчета быстрых и крайне долгих продаж.
# Быстрые продажи - те, что быстрее 30 дней
# Крайне долгие - те, что дольше  245 дней.

# %%
len(data.query('days_exposition > 1095'))

#Количество квартир, продающихся свыше 3 лет
# Out:
# 154

# %%
len(data.query('days_exposition > 730'))

#Количество квартир, продающихся свыше 2 лет
# Out:
# 717

# %% [markdown]
# Ограничим данные 3 годами, видим значительно сокращение количества таких квартир

# %%
data.drop(data[data['days_exposition'] > 1095].index,inplace=True)

# %%
data.boxplot('days_exposition')
# Out:
# <AxesSubplot:>

# %%
data.hist('days_exposition',range=(0,500))
# Out:
# array([[<AxesSubplot:title={'center':'days_exposition'}>]], dtype=object)

# %%
data['days_exposition'].describe()
# Out:
# count    19851.000000
# mean       170.608030
# std        196.598722
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        223.000000
# max       1095.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# # <b> Постройте гистограмму.</b>
# Какие факторы больше всего влияют на общую (полную) стоимость объекта?
# * Изучите, зависит ли цена от:
# общей площади;
# жилой площади;
# площади кухни;
# количества комнат;
# этажа, на котором расположена квартира (первый, последний, другой);
# даты размещения (день недели, месяц, год).
# * Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
# * Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце locality_name.
# * Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %%
data_new = data[['total_area', 'living_area', 'kitchen_area', 'rooms', 'type_floor', 'day', 'month', 'year', 'last_price']]
data_new.corr()
# Out:
#               total_area  living_area  kitchen_area     rooms       day  \
# total_area      1.000000     0.914931      0.541037  0.721106 -0.004513
# living_area     0.914931     1.000000      0.323685  0.838156 -0.003601
# kitchen_area    0.541037     0.323685      1.000000  0.165495 -0.011779
# rooms           0.721106     0.838156      0.165495  1.000000 -0.004016
# day            -0.004513    -0.003601     -0.011779 -0.004016  1.000000
# month           0.004934    -0.002554      0.004606 -0.002563  0.012969
# year           -0.077220    -0.067560     -0.048025 -0.045303 -0.008708
# last_price      0.670254     0.552945      0.483438  0.330615 -0.004548
#
#                  month      year  last_price
# total_area    0.004934 -0.077220    0.670254
# living_area  -0.002554 -0.067560    0.552945
# kitchen_area  0.004606 -0.048025    0.483438
# rooms        -0.002563 -0.045303    0.330615
# day           0.012969 -0.008708   -0.004548
# month         1.000000 -0.273924   -0.004048
# ...

# %% [markdown]
# Нас интересует последний столбец, чтобы определить коэффициент корреляции. Чем ближе к 1, тем более коэфф.положительный.
#
# В данном случае наибольшая корреляция выявилась между столбцом last_price и столбцами total_area, living_area, kitchen_area, rooms. Построим для них графики, используя сводные таблицы, где необходимый нам параметр будет сравниваться со средней ценой продажи.

# %%
data.pivot_table(index='rooms',values='last_price').plot(y='last_price', kind='bar', title='Корреляция между количеством комнат и средней ценой продажи');
data.pivot_table(index='type_floor',values='last_price').plot(y='last_price', kind='bar',  title='Корреляция между типом этажа и средней ценой продажи');
data.pivot_table(index='day',values='last_price').plot(y='last_price', kind='bar', title='Корреляция между днем публикации объявления и средней ценой продажи');
data.pivot_table(index='month',values='last_price').plot(y='last_price', kind='bar', title='Корреляция между месяцем публикации объявления и средней ценой продажи');
data.pivot_table(index='year',values='last_price').plot(y='last_price', kind='bar', title='Корреляция между годом публикации объявления и средней ценой продажи');

# %%
data.plot(x = 'total_area', y = 'last_price', kind='scatter', title='Корреляция между общей площадью квартиры и ценой продажи', alpha = 0.8);
data.plot(x = 'living_area', y = 'last_price', kind='scatter', title='Корреляция между жилой площадью квартиры и ценой продажи', alpha = 0.8);
data.plot(x = 'kitchen_area', y = 'last_price', kind='scatter', title='Корреляция между площадью кухни и ценой продажи', alpha = 0.8);

# %% [markdown]
# Выводы по графикам:
#
# Чем выше общая площадь квартиры, тем выше цена продажи, также влияют на нее и жилая площадь с площадью кухни.
#
# Есть отдельные категории элитных квартир с выбивающимися значениями по цене.
#
# Корреляция между количеством комнат и средней ценой продажи есть вплоть до 3 комнатных квартир. Для 4 комнатных квартир этот параметр имеет меньшее значение.
#
# Не первый и не последний этажи прожаются по средней цене выше, что все остальные. Это объяснимо: многие не любят эти этажи и на сайтах по подбору недвижимости есть даже отдельные кнопки, чтобы исключить их из поиска.
#
# День размещения объяления не имеет особой роли при продаже.
#
# В марте средняя цена квартир выше, минимальная - летом (в июле)
#
# В 2014 году имеется всплеск цен на недвижимость (этот год был годом "рекордного жилья"), после этого спрос на жилье для "парковки" денег у населения упал и рынок стабилизировался.

# %%
# Создаем сводную таблицу населенный пункт - цена за квадратный метр
top_data_pivot = data.pivot_table(index='locality_name', values='meter_price', aggfunc=['count', 'median'])
# Переименовываем "двухэтажные" названия столбцов
top_data_pivot.columns = ['count', 'median']
# Сортируем и выводим на экран первые 10 населенных пунктов, отсортированных по количеству объявлений
# с указанием медианного значения цены за 1 кв. метр в рублях, отформотировав стиль вывода значения до 2х знаков после запятой
top_data_pivot.sort_values('count', ascending=False).head(10).style.format({('median'): '{:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6cf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6cf9_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a6cf9_level0_col1" class="col_heading level0 col1" >median</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >locality_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6cf9_level0_row0" class="row_heading level0 row0" >санкт-петербург</th>
#       <td id="T_a6cf9_row0_col0" class="data row0 col0" >15055</td>
#       <td id="T_a6cf9_row0_col1" class="data row0 col1" >104687.50</td>
#     </tr>
#     <tr>
#       <th id="T_a6cf9_level0_row1" class="row_heading level0 row1" >поселок мурино</th>
#       <td id="T_a6cf9_row1_col0" class="data row1 col0" >547</td>
#       <td id="T_a6cf9_row1_col1" class="data row1 col1" >86042.64</td>
# ...

# %%
data['locality_name'].value_counts().head(10)
#Населенные пункты с наибольшим числом объявлений
# Out:
# санкт-петербург      15055
# поселок мурино         547
# поселок шушары         434
# всеволожск             396
# пушкин                 356
# колпино                334
# поселок парголово      325
# гатчина                301
# деревня кудрово        298
# выборг                 235
# Name: locality_name, dtype: int64

# %%
'''Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений.
Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра.
Эти данные можно найти по имени в столбце locality_name.
'''

print(data[data['locality_name']=='санкт-петербург'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='поселок мурино'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='поселок шушары'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='поселок парголово'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='деревня кудрово'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='гатчина'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='колпино'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='выборг'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='пушкин'].pivot_table(index='locality_name',values='meter_price'))
print(data[data['locality_name']=='всеволожск'].pivot_table(index='locality_name',values='meter_price'))
# Out:
#                    meter_price
# locality_name
# санкт-петербург  113868.535789
#                  meter_price
# locality_name
# поселок мурино  85688.669926
#                  meter_price
# locality_name
# поселок шушары  78481.773755
#                     meter_price
# locality_name
# поселок парголово  90259.743484
#                   meter_price
# locality_name
# деревня кудрово  92454.342295
#                 meter_price
# locality_name
# гатчина        68899.167184
#                 meter_price
# locality_name
# колпино        75398.328468
#                 meter_price
# locality_name
# выборг         58256.173466
#                  meter_price
# locality_name
# пушкин         103175.015664
#                 meter_price
# locality_name
# всеволожск     68674.623133

# %% [markdown]
# Самая большая стоимость квадратного метра в Санкт-Петербурге, далее идут Пушкин, Кудрово, Парголово, Мурино, Шушары, Колпино, Всеволожск, Гатчина, Выборг

# %%
'''
Ранее вы посчитали расстояние до центра в километрах.
Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра.
Опишите, как стоимость объектов зависит от расстояния до центра города.
'''

                              
data[data['locality_name']=='санкт-петербург'].pivot_table(index='cityCenters_nearest',values='last_price').plot(kind='bar');

# %% [markdown]
# Самая дорогая недвижимость находится в центре города, на расстоянии до 1 километра. Далее идет резкий спад цены. От 9 км и ниже - очередной спад цен. Есть пик на 20 км. Возможно, тут есть зависимость от отдельного вида жилья или конкретных районов.

# %% [markdown]
# # Шаг 5. Напишите общий вывод
#
# Не только на этапе предобработки данных, но в исследовательском анализе пришлось столкнуть с большим количеством выбросов данных. Природу части выбросов установить не удалось (например, размещение объявлений о продаже квартир свыше 4 лет).
# Были и очень большие по площади квартиры. Интересно, что таких квартир действительно много (хотя в общей пропорции они и теряются и выглядят, как выбросы).
#
# Быстрые продажи квартир - те, что быстрее 44 дней. Крайне долгие - те, что дольше 202 дней.
#
# Цена продажи зависит в большей степени от площади квартиры, на втором месте - от жилой площади.
#
# Самая дорогая недвижимость в самом центре города, далее цена сильно корректируется и начиная с удаленности 9 км и выше она снова падает в цене. Есть провалы по цене в районе 27 км от центра. Возможно, тут есть зависимость от отдельного вида жилья или конкретных районов.
# Самая большая стоимость квадратного метра в Санкт-Петербурге, далее идут Пушкин, Кудрово, Парголово, Мурино, Шушары, Колпино, Всеволожск, Гатчина, Выборг
